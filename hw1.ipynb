# %%
import pandas as pd
import numpy as np
from datetime import datetime
import itertools

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("offer_acceptance_offers.csv")
def conv_time(string):
    datetime_object = datetime.strptime(string, '%Y-%m-%d %H:%M:%S')
    return datetime_object

data['CREATED_ON_HQ'] = data['CREATED_ON_HQ'].apply(conv_time)
data.head()
# Out:
#                                           CARRIER_ID  \
# 0  16badfc6202cb3f8889e0f2779b19218af4cbb736e56ac...
# 1  0629d63476c157a6cfe234f7a34422eb0ad94998c2d082...
# 2  0629d63476c157a6cfe234f7a34422eb0ad94998c2d082...
# 3  0629d63476c157a6cfe234f7a34422eb0ad94998c2d082...
# 4  0629d63476c157a6cfe234f7a34422eb0ad94998c2d082...
#
#                                     REFERENCE_NUMBER       CREATED_ON_HQ  \
# 0  [\n  "ce3548db155049cc1ccce2da041cec607942e4f7... 2021-11-03 09:05:43
# 1  [\n  "ce3548db155049cc1ccce2da041cec607942e4f7... 2021-11-03 08:54:13
# 2  [\n  "ce3548db155049cc1ccce2da041cec607942e4f7... 2021-11-03 08:57:27
# 3  [\n  "ce3548db155049cc1ccce2da041cec607942e4f7... 2021-11-03 08:57:28
# 4  [\n  "ce3548db155049cc1ccce2da041cec607942e4f7... 2021-11-03 08:57:40
#
#    RATE_USD OFFER_TYPE  SELF_SERVE  IS_OFFER_APPROVED  AUTOMATICALLY_APPROVED  \
# 0   11610.0       pool       False              False                   False
# 1    9546.0       pool        True              False                   False
# 2    9159.0       pool        True               True                   False
# 3    9288.0       pool       False              False                   False
# 4    9159.0       pool       False               True                   False
#
#    MANUALLY_APPROVED  WAS_EVER_UNCOVERED  COVERING_OFFER  \
# 0              False               False           False
# 1              False               False           False
# 2               True               False            True
# 3              False               False           False
# 4               True               False           False
#
#    LOAD_DELIVERED_FROM_OFFER  RECOMMENDED_LOAD TRANSPORT_MODE  VALID
# 0                      False             False            FTL   True
# 1                      False              True            FTL   True
# 2                       True              True            FTL   True
# 3                      False             False            FTL   True
# 4                      False             False            FTL   True

# %% [markdown]
# ##### group offers by reference ID and exclude offers with more than one reference ID

# %%
FTL_data = data[data['TRANSPORT_MODE'] == 'FTL']
FTL_data = FTL_data.drop(['IS_OFFER_APPROVED', 'AUTOMATICALLY_APPROVED', 'MANUALLY_APPROVED'], axis=1)
FTL_data.shape
# Out:
# (358418, 12)

# %%
FTL_data.head()
# Out:
#                                           CARRIER_ID  \
# 0  16badfc6202cb3f8889e0f2779b19218af4cbb736e56ac...
# 1  0629d63476c157a6cfe234f7a34422eb0ad94998c2d082...
# 2  0629d63476c157a6cfe234f7a34422eb0ad94998c2d082...
# 3  0629d63476c157a6cfe234f7a34422eb0ad94998c2d082...
# 4  0629d63476c157a6cfe234f7a34422eb0ad94998c2d082...
#
#                                     REFERENCE_NUMBER       CREATED_ON_HQ  \
# 0  [\n  "ce3548db155049cc1ccce2da041cec607942e4f7... 2021-11-03 09:05:43
# 1  [\n  "ce3548db155049cc1ccce2da041cec607942e4f7... 2021-11-03 08:54:13
# 2  [\n  "ce3548db155049cc1ccce2da041cec607942e4f7... 2021-11-03 08:57:27
# 3  [\n  "ce3548db155049cc1ccce2da041cec607942e4f7... 2021-11-03 08:57:28
# 4  [\n  "ce3548db155049cc1ccce2da041cec607942e4f7... 2021-11-03 08:57:40
#
#    RATE_USD OFFER_TYPE  SELF_SERVE  WAS_EVER_UNCOVERED  COVERING_OFFER  \
# 0   11610.0       pool       False               False           False
# 1    9546.0       pool        True               False           False
# 2    9159.0       pool        True               False            True
# 3    9288.0       pool       False               False           False
# 4    9159.0       pool       False               False           False
#
#    LOAD_DELIVERED_FROM_OFFER  RECOMMENDED_LOAD TRANSPORT_MODE  VALID
# 0                      False             False            FTL   True
# 1                      False              True            FTL   True
# 2                       True              True            FTL   True
# 3                      False             False            FTL   True
# 4                      False             False            FTL   True

# %%
offers = pd.read_csv("offer_acceptance_orders.csv")
offers['ORDER_DATETIME_PST'] = offers['ORDER_DATETIME_PST'].apply(conv_time)
offers['PICKUP_DEADLINE_PST'] = offers['PICKUP_DEADLINE_PST'].apply(conv_time)

offers['diff_ORDER_PICKUP_DEADLINE'] = (offers['PICKUP_DEADLINE_PST'] - offers['ORDER_DATETIME_PST'])
offers.head()
# Out:
# /Users/nimayazdani/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (9,10,11,12,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                     REFERENCE_NUMBER  ORDER_DATETIME_PST  \
# 0  [\n  "291ba58f4d48916df29008a6e451994650458661... 2022-09-07 10:07:05
# 1  [\n  "e97bdf5ad99011a878f18c10b0df1f663f6b8f4a... 2022-05-19 09:21:39
# 2  [\n  "3cad7c1b5baf14968a6ee7c9b3649cb56193a40c... 2022-07-06 09:45:30
# 3  [\n  "c407879a0fc7dfe8dd40b8e0a8952eea0c5c850b... 2022-09-12 05:38:14
# 4  [\n  "e4ffed52c673af27ab35fcf4bb45e77becbbd95e... 2022-06-21 10:52:48
#
#   PICKUP_DEADLINE_PST DELIVERY_TIME_CONSTRAINT ORIGIN_3DIGIT_ZIP  \
# 0 2022-09-12 11:00:00                 SCHEDULE               386
# 1 2022-05-24 13:00:00                     NONE               670
# 2 2022-07-08 14:00:00                 SCHEDULE               952
# 3 2022-09-19 10:30:00                 SCHEDULE               381
# 4 2022-07-05 13:00:00                 SCHEDULE               917
#
#   DESTINATION_3DIGIT_ZIP  APPROXIMATE_DRIVING_ROUTE_MILEAGE  \
# 0                    080                             1035.0
# 1                    630                              414.0
# 2                    853                              703.0
# 3                    346                              753.0
# 4                    953                              345.0
#
#    PALLETIZED_LINEAR_FEET FD_ENABLED EXCLUSIVE_USE_REQUESTED HAZARDOUS  \
# 0                    22.0       True                    True     False
# 1                    45.0       True                    True     False
# 2                    20.0       True                    True     False
# 3                    52.0       True                   False     False
# 4                    48.0       True                    True     False
#
#   REEFER_ALLOWED STRAIGHT_TRUCK_ALLOWED  LOAD_BAR_COUNT  \
# 0           True                   True             0.0
# 1          False                   True             0.0
# 2          False                  False             0.0
# 3          False                  False             0.0
# 4          False                  False             0.0
#
#   LOAD_TO_RIDE_REQUESTED  ESTIMATED_COST_AT_ORDER TRANSPORT_MODE  \
# 0                   True                3864.3240            FTL
# 1                   True                1411.1181            FTL
# 2                   True                2385.0681            FTL
# 3                  False                2846.1141            FTL
# 4                  False                1695.6405            FTL
#
#   diff_ORDER_PICKUP_DEADLINE
# 0            5 days 00:52:55
# 1            5 days 03:38:21
# 2            2 days 04:14:30
# 3            7 days 04:51:46
# 4           14 days 02:07:12

# %%
joined = pd.merge(FTL_data, offers, on='REFERENCE_NUMBER', how='outer')
joined.sort_values(by = ['REFERENCE_NUMBER', 'CREATED_ON_HQ'], ascending = [True, True], na_position = 'first')
joined = joined[joined['OFFER_TYPE'] == 'quote']
joined.head(10)
# Out:
#                                               CARRIER_ID  \
# 93080  ba3be1d6cdc455d085fabeafa3b5f12ce439c09fb7f25f...
# 93081  d302498475ec90c0b6da20bb1067dbcd62a40e59784727...
# 93082  cb7593a6adb4b6339f9b0d794acc8903819db9e7c57624...
# 93083  8cd6cb7e1601eb5dcd0a0d3d8f62c2dd8ee483819f9130...
# 93084  10bb64fa1d284779a38ce9cc96b75ac7aa48c6a4bec7b2...
# 93085  98c4dc334adef12e86e9db7f757f9d0f11bf0ae1894fb8...
# 93086  98c4dc334adef12e86e9db7f757f9d0f11bf0ae1894fb8...
# 93087  cb7593a6adb4b6339f9b0d794acc8903819db9e7c57624...
# 93088  10bb64fa1d284779a38ce9cc96b75ac7aa48c6a4bec7b2...
# 93089  6d1c04303f57a11ff62f31ef5f4061966e3ad5b348d605...
#
#                                         REFERENCE_NUMBER       CREATED_ON_HQ  \
# 93080  [\n  "46d8930a62fddd24e3d682d7231b19a4e2f8b5d8... 2021-08-31 10:09:23
# 93081  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 05:41:19
# 93082  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 09:51:09
# 93083  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 07:48:15
# 93084  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 09:56:44
# 93085  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 06:26:08
# 93086  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 06:32:01
# 93087  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-06 11:14:57
# 93088  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 09:57:32
# 93089  [\n  "bc4e778ba19964fc301348c5f46c7d34773bd0e6... 2022-07-21 08:40:55
#
#        RATE_USD OFFER_TYPE SELF_SERVE WAS_EVER_UNCOVERED COVERING_OFFER  \
# 93080    3483.0      quote      False              False           True
# 93081    4902.0      quote      False              False          False
# 93082    2064.0      quote      False              False          False
# 93083    1935.0      quote      False               True          False
# 93084    1806.0      quote      False              False           True
# 93085    2193.0      quote      False              False          False
# 93086    1999.5      quote      False              False          False
# 93087    1806.0      quote      False              False          False
# 93088    1677.0      quote      False              False          False
# 93089    4515.0      quote      False              False          False
#
#       LOAD_DELIVERED_FROM_OFFER RECOMMENDED_LOAD  ... PALLETIZED_LINEAR_FEET  \
# 93080                      True            False  ...                   52.0
# 93081                     False            False  ...                   50.0
# 93082                     False            False  ...                   50.0
# 93083                     False            False  ...                   50.0
# 93084                      True            False  ...                   50.0
# 93085                     False            False  ...                   50.0
# 93086                     False            False  ...                   50.0
# 93087                     False            False  ...                   50.0
# 93088                     False            False  ...                   50.0
# 93089                     False            False  ...                   51.0
#
#       FD_ENABLED EXCLUSIVE_USE_REQUESTED HAZARDOUS REEFER_ALLOWED  \
# 93080       True                   False     False           True
# 93081       True                   False     False           True
# 93082       True                   False     False           True
# 93083       True                   False     False           True
# 93084       True                   False     False           True
# 93085       True                   False     False           True
# 93086       True                   False     False           True
# 93087       True                   False     False           True
# 93088       True                   False     False           True
# 93089       True                    True     False          False
#
#       STRAIGHT_TRUCK_ALLOWED LOAD_BAR_COUNT  LOAD_TO_RIDE_REQUESTED  \
# 93080                   True            0.0                   False
# 93081                   True            0.0                   False
# 93082                   True            0.0                   False
# 93083                   True            0.0                   False
# 93084                   True            0.0                   False
# 93085                   True            0.0                   False
# 93086                   True            0.0                   False
# 93087                   True            0.0                   False
# 93088                   True            0.0                   False
# 93089                  False            0.0                    True
#
#        ESTIMATED_COST_AT_ORDER TRANSPORT_MODE_y
# 93080                3528.2016              FTL
# 93081                1995.4623              FTL
# 93082                1995.4623              FTL
# 93083                1995.4623              FTL
# 93084                1995.4623              FTL
# 93085                1995.4623              FTL
# 93086                1995.4623              FTL
# 93087                1995.4623              FTL
# 93088                1995.4623              FTL
# 93089                3798.4050              FTL
#
# [10 rows x 28 columns]

# %% [markdown]
# #### total revenue from flock algorithm

# %%
true_joined = joined[joined['LOAD_DELIVERED_FROM_OFFER'] == True]
# all_sales = true_joined.groupby('REFERENCE_NUMBER').sum()
total_sales = true_joined['RATE_USD'].mean()
total_sales
# Out:
# 3379.3299538289925

# %%
test_data = joined[:10000]
test_data
# Out:
#                                                CARRIER_ID  \
# 93080   ba3be1d6cdc455d085fabeafa3b5f12ce439c09fb7f25f...
# 93081   d302498475ec90c0b6da20bb1067dbcd62a40e59784727...
# 93082   cb7593a6adb4b6339f9b0d794acc8903819db9e7c57624...
# 93083   8cd6cb7e1601eb5dcd0a0d3d8f62c2dd8ee483819f9130...
# 93084   10bb64fa1d284779a38ce9cc96b75ac7aa48c6a4bec7b2...
# ...                                                   ...
# 103075  0e74fa5f84db6f9d5f38b50b205450660387ad8cd310c3...
# 103076  77f9732c1e4bb3caedbe905cb1c9fa0293775e1486a763...
# 103077  9ef42d70a0fada18a939e03bf1de4b6669011f5bfcd6b6...
# 103078  77f9732c1e4bb3caedbe905cb1c9fa0293775e1486a763...
# 103079  1ba871abebe0545358131ecd30f659c810463cea5022b7...
#
#                                          REFERENCE_NUMBER       CREATED_ON_HQ  \
# 93080   [\n  "46d8930a62fddd24e3d682d7231b19a4e2f8b5d8... 2021-08-31 10:09:23
# 93081   [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 05:41:19
# 93082   [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 09:51:09
# 93083   [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 07:48:15
# 93084   [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 09:56:44
# ...                                                   ...                 ...
# 103075  [\n  "528b5bad2f751dcf66bc5855187bb53b341384fa... 2020-10-19 08:51:26
# 103076  [\n  "528b5bad2f751dcf66bc5855187bb53b341384fa... 2020-10-19 08:56:39
# 103077  [\n  "528b5bad2f751dcf66bc5855187bb53b341384fa... 2020-10-20 08:06:38
# 103078  [\n  "528b5bad2f751dcf66bc5855187bb53b341384fa... 2020-10-19 09:01:45
# 103079  [\n  "d6eaa7c5bb85debf7956e664f18108cce07e69b8... 2021-10-11 11:15:13
#
#         RATE_USD OFFER_TYPE SELF_SERVE WAS_EVER_UNCOVERED COVERING_OFFER  \
# 93080     3483.0      quote      False              False           True
# 93081     4902.0      quote      False              False          False
# 93082     2064.0      quote      False              False          False
# 93083     1935.0      quote      False               True          False
# 93084     1806.0      quote      False              False           True
# ...          ...        ...        ...                ...            ...
# 103075    1806.0      quote      False              False          False
# 103076    1870.5      quote      False              False          False
# 103077    1419.0      quote      False              False          False
# 103078    1548.0      quote      False               True          False
# 103079    2322.0      quote      False              False          False
#
#        LOAD_DELIVERED_FROM_OFFER RECOMMENDED_LOAD  ... PALLETIZED_LINEAR_FEET  \
# 93080                       True            False  ...                   52.0
# 93081                      False            False  ...                   50.0
# 93082                      False            False  ...                   50.0
# 93083                      False            False  ...                   50.0
# 93084                       True            False  ...                   50.0
# ...                          ...              ...  ...                    ...
# 103075                     False            False  ...                   51.0
# 103076                     False            False  ...                   51.0
# 103077                     False            False  ...                   51.0
# 103078                     False            False  ...                   51.0
# 103079                     False            False  ...                   50.0
#
#        FD_ENABLED EXCLUSIVE_USE_REQUESTED HAZARDOUS REEFER_ALLOWED  \
# 93080        True                   False     False           True
# 93081        True                   False     False           True
# 93082        True                   False     False           True
# 93083        True                   False     False           True
# 93084        True                   False     False           True
# ...           ...                     ...       ...            ...
# 103075       True                   False     False           True
# 103076       True                   False     False           True
# 103077       True                   False     False           True
# 103078       True                   False     False           True
# 103079       True                    True     False           True
#
#        STRAIGHT_TRUCK_ALLOWED LOAD_BAR_COUNT  LOAD_TO_RIDE_REQUESTED  \
# 93080                    True            0.0                   False
# 93081                    True            0.0                   False
# 93082                    True            0.0                   False
# 93083                    True            0.0                   False
# 93084                    True            0.0                   False
# ...                       ...            ...                     ...
# 103075                   True            0.0                   False
# 103076                   True            0.0                   False
# 103077                   True            0.0                   False
# 103078                   True            0.0                   False
# 103079                   True            0.0                   False
#
#         ESTIMATED_COST_AT_ORDER TRANSPORT_MODE_y
# 93080                 3528.2016              FTL
# 93081                 1995.4623              FTL
# 93082                 1995.4623              FTL
# 93083                 1995.4623              FTL
# 93084                 1995.4623              FTL
# ...                         ...              ...
# 103075                1543.2141              FTL
# 103076                1543.2141              FTL
# 103077                1543.2141              FTL
# 103078                1543.2141              FTL
# 103079                2385.0552              FTL
#
# [10000 rows x 28 columns]

# %%
ans = []
for n in test_data['REFERENCE_NUMBER'].unique():
    SecMeth = int(len(test_data[test_data['REFERENCE_NUMBER'] == n]) / np.e)
    GB = test_data[test_data['REFERENCE_NUMBER'] == n].sort_values(by='CREATED_ON_HQ', ascending=True)
    record = np.array(GB['RATE_USD'])[SecMeth]
    offer = 0
    for num in np.array((GB['RATE_USD'])[SecMeth:-1]):
        if num > record:
            offer = num
            break
        else:
            offer = np.array(GB['RATE_USD'])[-1]
        ans.append(offer)

# %%
np.mean(ans)
# Out:
# 3840.5346546807805

# %%
np.array(FTL_data['CREATED_ON_HQ'])
# Out:
# array(['2021-11-03 09:05:43', '2021-11-03 08:54:13',
#        '2021-11-03 08:57:27', ..., '2021-11-15 11:25:58',
#        '2021-04-26 10:00:23', '2022-09-02 05:33:02'], dtype=object)

# %%
# turn over 37% of the offers and then after that choose the next offer that is a record

# %%
#1 on the sample size i did it made about 300$ more per shipment
#2 using the floor round is a bit more conservative and boosts the average rate by about 100$
#3 you have to know the number of offers before you calculate when to stop

#1 the secretary approach now is conditional because the second stopping point depends on when we stop for 
#the first pool shipment
#2 Somehow we have to include a manual point of when to stop for the first of the 2 pool shipments because if 
#we wait too long to accept our first pool offer then we have less to choose from for our second pool offer

# %%
# Get one hot encoding of columns B
one_hot = pd.get_dummies(joined['B'])
# Drop column B as it is now encoded
df = df.drop('B',axis = 1)
# Join the encoded df
df = df.join(one_hot)
df

# %%
df = pd.merge(FTL_data, offers, on='REFERENCE_NUMBER', how='inner')
df.sort_values(by = ['REFERENCE_NUMBER', 'CREATED_ON_HQ'], ascending = [True, True], na_position = 'first')
df = df[df['OFFER_TYPE'] == 'quote']
df.head()
# Out:
#                                           CARRIER_ID  \
# 0  ba3be1d6cdc455d085fabeafa3b5f12ce439c09fb7f25f...
# 1  d302498475ec90c0b6da20bb1067dbcd62a40e59784727...
# 2  cb7593a6adb4b6339f9b0d794acc8903819db9e7c57624...
# 3  8cd6cb7e1601eb5dcd0a0d3d8f62c2dd8ee483819f9130...
# 4  10bb64fa1d284779a38ce9cc96b75ac7aa48c6a4bec7b2...
#
#                                     REFERENCE_NUMBER       CREATED_ON_HQ  \
# 0  [\n  "46d8930a62fddd24e3d682d7231b19a4e2f8b5d8... 2021-08-31 10:09:23
# 1  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 05:41:19
# 2  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 09:51:09
# 3  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 07:48:15
# 4  [\n  "3b74ebf4c440a5ff141cafdc9b3e20230fc18360... 2021-10-08 09:56:44
#
#    RATE_USD OFFER_TYPE  SELF_SERVE  WAS_EVER_UNCOVERED  COVERING_OFFER  \
# 0    3483.0      quote       False               False            True
# 1    4902.0      quote       False               False           False
# 2    2064.0      quote       False               False           False
# 3    1935.0      quote       False                True           False
# 4    1806.0      quote       False               False            True
#
#    LOAD_DELIVERED_FROM_OFFER  RECOMMENDED_LOAD  ... FD_ENABLED  \
# 0                       True             False  ...       True
# 1                      False             False  ...       True
# 2                      False             False  ...       True
# 3                      False             False  ...       True
# 4                       True             False  ...       True
#
#    EXCLUSIVE_USE_REQUESTED HAZARDOUS REEFER_ALLOWED STRAIGHT_TRUCK_ALLOWED  \
# 0                    False     False           True                   True
# 1                    False     False           True                   True
# 2                    False     False           True                   True
# 3                    False     False           True                   True
# 4                    False     False           True                   True
#
#   LOAD_BAR_COUNT LOAD_TO_RIDE_REQUESTED  ESTIMATED_COST_AT_ORDER  \
# 0            0.0                  False                3528.2016
# 1            0.0                  False                1995.4623
# 2            0.0                  False                1995.4623
# 3            0.0                  False                1995.4623
# 4            0.0                  False                1995.4623
#
#    TRANSPORT_MODE_y diff_ORDER_PICKUP_DEADLINE
# 0               FTL            1 days 23:49:39
# 1               FTL           12 days 07:10:12
# 2               FTL           12 days 07:10:12
# 3               FTL           12 days 07:10:12
# 4               FTL           12 days 07:10:12
#
# [5 rows x 29 columns]

# %%
df['diff_ORDER_PICKUP_DEADLINE'] = df['diff_ORDER_PICKUP_DEADLINE'].dt.total_seconds()

# %%
df.corr()
# Out:
#                                    RATE_USD  SELF_SERVE  WAS_EVER_UNCOVERED  \
# RATE_USD                           1.000000    0.001978           -0.001574
# SELF_SERVE                         0.001978    1.000000           -0.055376
# WAS_EVER_UNCOVERED                -0.001574   -0.055376            1.000000
# COVERING_OFFER                    -0.003495   -0.089712           -0.114766
# LOAD_DELIVERED_FROM_OFFER         -0.003435   -0.092081           -0.112455
# RECOMMENDED_LOAD                   0.001596    0.616471           -0.053399
# VALID                             -0.004666    0.065340           -0.021033
# APPROXIMATE_DRIVING_ROUTE_MILEAGE  0.003803   -0.016211           -0.022027
# PALLETIZED_LINEAR_FEET             0.004150   -0.089418            0.011705
# LOAD_BAR_COUNT                    -0.000490    0.015624            0.001465
# ESTIMATED_COST_AT_ORDER            0.005820   -0.036166           -0.012519
# diff_ORDER_PICKUP_DEADLINE        -0.000695    0.035946            0.063504
#
#                                    COVERING_OFFER  LOAD_DELIVERED_FROM_OFFER  \
# RATE_USD                                -0.003495                  -0.003435
# SELF_SERVE                              -0.089712                  -0.092081
# WAS_EVER_UNCOVERED                      -0.114766                  -0.112455
# COVERING_OFFER                           1.000000                   0.981879
# LOAD_DELIVERED_FROM_OFFER                0.981879                   1.000000
# RECOMMENDED_LOAD                        -0.110304                  -0.110770
# VALID                                    0.126409                   0.124410
# APPROXIMATE_DRIVING_ROUTE_MILEAGE       -0.055364                  -0.056506
# PALLETIZED_LINEAR_FEET                   0.002011                   0.001845
# LOAD_BAR_COUNT                          -0.002315                  -0.002616
# ESTIMATED_COST_AT_ORDER                 -0.031002                  -0.032394
# diff_ORDER_PICKUP_DEADLINE              -0.034946                  -0.043247
#
#                                    RECOMMENDED_LOAD     VALID  \
# RATE_USD                                   0.001596 -0.004666
# SELF_SERVE                                 0.616471  0.065340
# WAS_EVER_UNCOVERED                        -0.053399 -0.021033
# COVERING_OFFER                            -0.110304  0.126409
# LOAD_DELIVERED_FROM_OFFER                 -0.110770  0.124410
# RECOMMENDED_LOAD                           1.000000  0.040611
# VALID                                      0.040611  1.000000
# APPROXIMATE_DRIVING_ROUTE_MILEAGE         -0.007727 -0.005376
# PALLETIZED_LINEAR_FEET                    -0.069412  0.001777
# LOAD_BAR_COUNT                             0.010627 -0.002624
# ESTIMATED_COST_AT_ORDER                   -0.005629 -0.001686
# diff_ORDER_PICKUP_DEADLINE                 0.025546 -0.004469
#
#                                    APPROXIMATE_DRIVING_ROUTE_MILEAGE  \
# RATE_USD                                                    0.003803
# SELF_SERVE                                                 -0.016211
# WAS_EVER_UNCOVERED                                         -0.022027
# COVERING_OFFER                                             -0.055364
# LOAD_DELIVERED_FROM_OFFER                                  -0.056506
# RECOMMENDED_LOAD                                           -0.007727
# VALID                                                      -0.005376
# APPROXIMATE_DRIVING_ROUTE_MILEAGE                           1.000000
# PALLETIZED_LINEAR_FEET                                      0.049537
# LOAD_BAR_COUNT                                              0.038582
# ESTIMATED_COST_AT_ORDER                                     0.895278
# diff_ORDER_PICKUP_DEADLINE                                 -0.040559
#
#                                    PALLETIZED_LINEAR_FEET  LOAD_BAR_COUNT  \
# RATE_USD                                         0.004150       -0.000490
# SELF_SERVE                                      -0.089418        0.015624
# WAS_EVER_UNCOVERED                               0.011705        0.001465
# COVERING_OFFER                                   0.002011       -0.002315
# LOAD_DELIVERED_FROM_OFFER                        0.001845       -0.002616
# RECOMMENDED_LOAD                                -0.069412        0.010627
# VALID                                            0.001777       -0.002624
# APPROXIMATE_DRIVING_ROUTE_MILEAGE                0.049537        0.038582
# PALLETIZED_LINEAR_FEET                           1.000000       -0.001264
# LOAD_BAR_COUNT                                  -0.001264        1.000000
# ESTIMATED_COST_AT_ORDER                          0.075916        0.037325
# diff_ORDER_PICKUP_DEADLINE                       0.033462        0.051645
#
#                                    ESTIMATED_COST_AT_ORDER  \
# RATE_USD                                          0.005820
# SELF_SERVE                                       -0.036166
# WAS_EVER_UNCOVERED                               -0.012519
# COVERING_OFFER                                   -0.031002
# LOAD_DELIVERED_FROM_OFFER                        -0.032394
# RECOMMENDED_LOAD                                 -0.005629
# VALID                                            -0.001686
# APPROXIMATE_DRIVING_ROUTE_MILEAGE                 0.895278
# PALLETIZED_LINEAR_FEET                            0.075916
# LOAD_BAR_COUNT                                    0.037325
# ESTIMATED_COST_AT_ORDER                           1.000000
# diff_ORDER_PICKUP_DEADLINE                       -0.037253
#
#                                    diff_ORDER_PICKUP_DEADLINE
# RATE_USD                                            -0.000695
# SELF_SERVE                                           0.035946
# WAS_EVER_UNCOVERED                                   0.063504
# COVERING_OFFER                                      -0.034946
# LOAD_DELIVERED_FROM_OFFER                           -0.043247
# RECOMMENDED_LOAD                                     0.025546
# VALID                                               -0.004469
# APPROXIMATE_DRIVING_ROUTE_MILEAGE                   -0.040559
# PALLETIZED_LINEAR_FEET                               0.033462
# LOAD_BAR_COUNT                                       0.051645
# ESTIMATED_COST_AT_ORDER                             -0.037253
# diff_ORDER_PICKUP_DEADLINE                           1.000000

# %%
df.columns
# Out:
# Index(['CARRIER_ID', 'REFERENCE_NUMBER', 'CREATED_ON_HQ', 'RATE_USD',
#        'OFFER_TYPE', 'SELF_SERVE', 'WAS_EVER_UNCOVERED', 'COVERING_OFFER',
#        'LOAD_DELIVERED_FROM_OFFER', 'RECOMMENDED_LOAD', 'TRANSPORT_MODE_x',
#        'VALID', 'ORDER_DATETIME_PST', 'PICKUP_DEADLINE_PST',
#        'DELIVERY_TIME_CONSTRAINT', 'ORIGIN_3DIGIT_ZIP',
#        'DESTINATION_3DIGIT_ZIP', 'APPROXIMATE_DRIVING_ROUTE_MILEAGE',
#        'PALLETIZED_LINEAR_FEET', 'FD_ENABLED', 'EXCLUSIVE_USE_REQUESTED',
#        'HAZARDOUS', 'REEFER_ALLOWED', 'STRAIGHT_TRUCK_ALLOWED',
#        'LOAD_BAR_COUNT', 'LOAD_TO_RIDE_REQUESTED', 'ESTIMATED_COST_AT_ORDER',
#        'TRANSPORT_MODE_y'],
#       dtype='object')

# %%
df['DESTINATION_3DIGIT_ZIP'].nunique()
# Out:
# 822
