# %%
import Clean
import pandas as pd
import numpy as np
import Model
import SecretaryMethod
from sklearn.linear_model import LinearRegression

# %%
offers = pd.read_csv("offer_acceptance_offers.csv",low_memory=False)
orders = pd.read_csv('offer_acceptance_orders.csv',low_memory=False)

# %%
orders = Clean.clean_orders(orders)
offers = Clean.clean_offers(offers)
train,test = Clean.create_train_test_orders(orders)
joinedDF = Clean.createJoinedDF(offers,train)

# %%
# variables used for modeling
bool_column_names = [
 'FD_ENABLED',
 'EXCLUSIVE_USE_REQUESTED',
 'HAZARDOUS',
 'REEFER_ALLOWED',
 'STRAIGHT_TRUCK_ALLOWED',
 'LOAD_TO_RIDE_REQUESTED',
]

numerical_loggable_column_names = [
 'APPROXIMATE_DRIVING_ROUTE_MILEAGE',
 'PALLETIZED_LINEAR_FEET',
 'SECONDS_BETWEEN_ORDER_AND_DEADLINE',
 'LOAD_BAR_COUNT',
 'ESTIMATED_COST_AT_ORDER'
]
x = numerical_loggable_column_names + bool_column_names

# %%
#AverageRateModel = Model.Train_model(trainDF,x,'Average_Rate')
NUMBER_OFFERSModel = Model.Train_model(joinedDF,x,'NUMBER_OFFERS')

# %%
testDF = Model.PrepareTestSet(test,NUMBER_OFFERSModel,x,'EstimatedNumOffs')

# %%
dic = SecretaryMethod.runSecretaryMethod(testDF['REFERENCE_NUMBER'],testDF,offers)

# %%
len(dic['ReferenceNumbers'])
# Out:
# 1825

# %%
testDF
# Out:
#                                        REFERENCE_NUMBER  ORDER_DATETIME_PST  \
# 0     [\n  "bf1547a008a8cae78f980f0da9af48794096207a... 2022-09-16 13:13:01
# 1     [\n  "c0c81682f295dc60ae0f27533f91472ba0cfff7e... 2022-03-14 14:12:00
# 2     [\n  "8bcc6860a5076f426977ba74bd1272f61562bbb9... 2021-07-08 10:30:36
# 3     [\n  "99512003c61fa12e7139a672a34876ea7755158a... 2022-01-20 10:35:26
# 4     [\n  "240984f44f12e5c47cfd9d8f0b482bf5d9f743ae... 2022-02-03 15:13:08
# ...                                                 ...                 ...
# 3983  [\n  "db44f796d6f64646e4c811d4ca3be487c959b610... 2021-09-03 09:46:50
# 3984  [\n  "01a840fa12aaee5df346f3e00f7558fe41900a1e... 2021-09-01 13:35:35
# 3985  [\n  "18a6a4337ef9bc38139f21fa22df258284574bd7... 2020-10-01 07:24:30
# 3986  [\n  "9204d9e9630d9e8fb85dcba050ad9c0d2fa25cdd... 2021-11-23 14:04:42
# 3987  [\n  "a1ba1d45f87d5fe6221beab9e6a4b9a7da17843e... 2022-06-08 09:23:25
#
#      PICKUP_DEADLINE_PST DELIVERY_TIME_CONSTRAINT ORIGIN_3DIGIT_ZIP  \
# 0    2022-09-19 13:00:00                 SCHEDULE               305
# 1    2022-03-22 12:00:00                 SCHEDULE               767
# 2    2021-07-13 14:00:00                     NONE               923
# 3    2022-02-02 13:00:00                 SCHEDULE               293
# 4    2022-02-04 14:30:00                     NONE               846
# ...                  ...                      ...               ...
# 3983 2021-09-07 14:00:00                 SCHEDULE               750
# 3984 2021-09-08 13:00:00                 SCHEDULE               296
# 3985 2020-10-07 11:45:00                     NONE               775
# 3986 2021-12-02 15:30:00                     NONE               917
# 3987 2022-06-13 15:00:00                 SCHEDULE               906
#
#      DESTINATION_3DIGIT_ZIP  APPROXIMATE_DRIVING_ROUTE_MILEAGE  \
# 0                       713                              601.0
# 1                       923                             1352.0
# 2                       600                             1990.0
# 3                       432                              499.0
# 4                       948                              767.0
# ...                     ...                                ...
# 3983                    785                              534.0
# 3984                    319                              260.0
# 3985                    780                              250.0
# 3986                    463                             2024.0
# 3987                    760                             1405.0
#
#       PALLETIZED_LINEAR_FEET  FD_ENABLED EXCLUSIVE_USE_REQUESTED HAZARDOUS  \
# 0                       45.0        True                    True     False
# 1                       48.0        True                   False     False
# 2                       52.0        True                    True     False
# 3                       52.0        True                    True     False
# 4                       49.0        True                   False     False
# ...                      ...         ...                     ...       ...
# 3983                    50.0        True                   False     False
# 3984                    52.0        True                    True     False
# 3985                    49.0        True                    True     False
# 3986                    52.0        True                   False     False
# 3987                    52.0        True                    True     False
#
#      REEFER_ALLOWED STRAIGHT_TRUCK_ALLOWED  LOAD_BAR_COUNT  \
# 0             False                  False             0.0
# 1              True                   True             0.0
# 2              True                  False             0.0
# 3             False                   True             0.0
# 4              True                   True             0.0
# ...             ...                    ...             ...
# 3983           True                   True             0.0
# 3984           True                   True             0.0
# 3985           True                   True             0.0
# 3986          False                   True             0.0
# 3987           True                  False             2.0
#
#      LOAD_TO_RIDE_REQUESTED  ESTIMATED_COST_AT_ORDER TRANSPORT_MODE  \
# 0                      True                1907.2134            FTL
# 1                      True                2546.3568            FTL
# 2                     False                7880.9970            FTL
# 3                      True                2220.7995            FTL
# 4                     False                2384.5263            FTL
# ...                     ...                      ...            ...
# 3983                  False                1012.6242            FTL
# 3984                   True                1287.9360            FTL
# 3985                   True                 696.9225            FTL
# 3986                  False                9869.4288            FTL
# 3987                  False                4942.4415            FTL
#
#      Time_between_Order_pickup  SECONDS_BETWEEN_ORDER_AND_DEADLINE  \
# 0              2 days 23:46:59                            258419.0
# 1              7 days 21:48:00                            683280.0
# 2              5 days 03:29:24                            444564.0
# 3             13 days 02:24:34                           1131874.0
# 4              0 days 23:16:52                             83812.0
# ...                        ...                                 ...
# 3983           4 days 04:13:10                            360790.0
# 3984           6 days 23:24:25                            602665.0
# 3985           6 days 04:20:30                            534030.0
# 3986           9 days 01:25:18                            782718.0
# 3987           5 days 05:36:35                            452195.0
#
#       EstimatedNumOffs
# 0                  4.0
# 1                  4.0
# 2                  4.0
# 3                  4.0
# 4                  3.0
# ...                ...
# 3983               3.0
# 3984               3.0
# 3985               3.0
# 3986               4.0
# 3987               4.0
#
# [3988 rows x 20 columns]
